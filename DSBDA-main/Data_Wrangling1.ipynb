# %%
import pandas as pd
import numpy as np

csv_data = pd.read_csv("/home/csl4/Downloads/Diabetes Missing Data.csv")
print(csv_data)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
print(csv_data.head())

# to print top 10
print(csv_data.head(10))
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# ...

# %%
print(csv_data.tail())

# print last 10 values
print(csv_data.tail(10))
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 763              0.171   63      0
# 764              0.340   27      0
# 765              0.245   30      0
# 766              0.349   47      1
# 767              0.315   23      0
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 758         1    106.0          76.0        NaN            NaN  37.5
# 759         6    190.0          92.0        NaN            NaN  35.5
# 760         2     88.0          58.0       26.0           16.0  28.4
# ...

# %%
# print from 3 to last row
print(csv_data.tail(-3))
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# 5           5    116.0          74.0        NaN            NaN  25.6
# 6           3     78.0          50.0       32.0           88.0  31.0
# 7          10    115.0           NaN        NaN            NaN  35.3
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 3                0.167   21      0
# 4                2.288   33      1
# ...

# %%
print(csv_data.columns)
# Out:
# Index(['Pregnant', 'Glucose', 'Diastolic_BP', 'Skin_Fold', 'Serum_Insulin',
#        'BMI', 'Diabetes_Pedigree', 'Age', 'Class'],
#       dtype='object')

# %%
csv_data.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
csv_data.dtypes
# Out:
# Pregnant               int64
# Glucose              float64
# Diastolic_BP         float64
# Skin_Fold            float64
# Serum_Insulin        float64
# BMI                  float64
# Diabetes_Pedigree    float64
# Age                    int64
# Class                  int64
# dtype: object

# %%
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pregnant           768 non-null    int64
#  1   Glucose            763 non-null    float64
#  2   Diastolic_BP       733 non-null    float64
#  3   Skin_Fold          541 non-null    float64
#  4   Serum_Insulin      394 non-null    float64
#  5   BMI                757 non-null    float64
#  6   Diabetes_Pedigree  768 non-null    float64
#  7   Age                768 non-null    int64
#  8   Class              768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %%
csv_data.size
# Out:
# 6912

# %%
csv_data.shape
# Out:
# (768, 9)

# %%
print(csv_data["BMI"].head())
# Out:
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# Name: BMI, dtype: float64

# %%
csv_data.loc[2,'BMI']   #loc is label based   # loc[row,col]
# Out:
# 23.3

# %%
csv_data.loc[4]
# Out:
# Pregnant               0.000
# Glucose              137.000
# Diastolic_BP          40.000
# Skin_Fold             35.000
# Serum_Insulin        168.000
# BMI                   43.100
# Diabetes_Pedigree      2.288
# Age                   33.000
# Class                  1.000
# Name: 4, dtype: float64

# %%
csv_data.loc[1:3]  # loc is label based and last index is inclusive
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
#
#    Diabetes_Pedigree  Age  Class
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0

# %%
csv_data.iloc[1:3]  #iloc is index based and last value is exlcusive
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
#
#    Diabetes_Pedigree  Age  Class
# 1              0.351   31      0
# 2              0.672   32      1

# %% [markdown]
# ## DATA FILTERING

# %%
print(csv_data[csv_data.Age == 32])
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 2           8    183.0          64.0        NaN            NaN  23.3
# 15          7    100.0           NaN        NaN            NaN  30.0
# 19          1    115.0          70.0       30.0           96.0  34.6
# 65          5     99.0          74.0       27.0            NaN  29.0
# 164         0    131.0          88.0        NaN            NaN  31.6
# 180         6     87.0          80.0        NaN            NaN  23.2
# 202         0    108.0          68.0       20.0            NaN  27.3
# 217         6    125.0          68.0       30.0          120.0  30.0
# 218         5     85.0          74.0       22.0            NaN  29.0
# 238         9    164.0          84.0       21.0            NaN  30.8
# 378         4    156.0          75.0        NaN            NaN  48.3
# 539         3    129.0          92.0       49.0          155.0  36.4
# 563         6     99.0          60.0       19.0           54.0  26.9
# ...

# %%
print(csv_data[(csv_data.Age == 32) & (csv_data.BMI == 30.0)])   # using & condition for filtering
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 15          7    100.0           NaN        NaN            NaN  30.0
# 217         6    125.0          68.0       30.0          120.0  30.0
#
#      Diabetes_Pedigree  Age  Class
# 15               0.484   32      1
# 217              0.464   32      0

# %%
print(csv_data.describe())   # describe the data with count,mean,std,etc.
# Out:
#          Pregnant     Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin  \
# count  768.000000  763.000000    733.000000  541.000000     394.000000
# mean     3.845052  121.686763     72.405184   29.153420     155.548223
# std      3.369578   30.535641     12.382158   10.476982     118.775855
# min      0.000000   44.000000     24.000000    7.000000      14.000000
# 25%      1.000000   99.000000     64.000000   22.000000      76.250000
# 50%      3.000000  117.000000     72.000000   29.000000     125.000000
# 75%      6.000000  141.000000     80.000000   36.000000     190.000000
# max     17.000000  199.000000    122.000000   99.000000     846.000000
#
#               BMI  Diabetes_Pedigree         Age       Class
# count  757.000000         768.000000  768.000000  768.000000
# mean    32.457464           0.471876   33.240885    0.348958
# std      6.924988           0.331329   11.760232    0.476951
# min     18.200000           0.078000   21.000000    0.000000
# ...

# %%
print(csv_data.describe(include="all"))
# Out:
#          Pregnant     Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin  \
# count  768.000000  763.000000    733.000000  541.000000     394.000000
# mean     3.845052  121.686763     72.405184   29.153420     155.548223
# std      3.369578   30.535641     12.382158   10.476982     118.775855
# min      0.000000   44.000000     24.000000    7.000000      14.000000
# 25%      1.000000   99.000000     64.000000   22.000000      76.250000
# 50%      3.000000  117.000000     72.000000   29.000000     125.000000
# 75%      6.000000  141.000000     80.000000   36.000000     190.000000
# max     17.000000  199.000000    122.000000   99.000000     846.000000
#
#               BMI  Diabetes_Pedigree         Age       Class
# count  757.000000         768.000000  768.000000  768.000000
# mean    32.457464           0.471876   33.240885    0.348958
# std      6.924988           0.331329   11.760232    0.476951
# min     18.200000           0.078000   21.000000    0.000000
# ...

# %%
print(csv_data.describe(include=[np.float64]))
# Out:
#           Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin         BMI  \
# count  763.000000    733.000000  541.000000     394.000000  757.000000
# mean   121.686763     72.405184   29.153420     155.548223   32.457464
# std     30.535641     12.382158   10.476982     118.775855    6.924988
# min     44.000000     24.000000    7.000000      14.000000   18.200000
# 25%     99.000000     64.000000   22.000000      76.250000   27.500000
# 50%    117.000000     72.000000   29.000000     125.000000   32.300000
# 75%    141.000000     80.000000   36.000000     190.000000   36.600000
# max    199.000000    122.000000   99.000000     846.000000   67.100000
#
#        Diabetes_Pedigree
# count         768.000000
# mean            0.471876
# std             0.331329
# min             0.078000
# 25%             0.243750
# 50%             0.372500
# 75%             0.626250
# max             2.420000

# %%
csv_data.isnull()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0       False    False         False      False           True  False
# 1       False    False         False      False           True  False
# 2       False    False         False       True           True  False
# 3       False    False         False      False          False  False
# 4       False    False         False      False          False  False
# ..        ...      ...           ...        ...            ...    ...
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 0                False  False  False
# 1                False  False  False
# ...

# %%
csv_data.isna()
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin    BMI  \
# 0       False    False         False      False           True  False
# 1       False    False         False      False           True  False
# 2       False    False         False       True           True  False
# 3       False    False         False      False          False  False
# 4       False    False         False      False          False  False
# ..        ...      ...           ...        ...            ...    ...
# 763     False    False         False      False          False  False
# 764     False    False         False      False           True  False
# 765     False    False         False      False          False  False
# 766     False    False         False       True           True  False
# 767     False    False         False      False           True  False
#
#      Diabetes_Pedigree    Age  Class
# 0                False  False  False
# 1                False  False  False
# ...

# %%
csv_data.dropna() # remove the null value
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# 6           3     78.0          50.0       32.0           88.0  31.0
# 8           2    197.0          70.0       45.0          543.0  30.5
# 13          1    189.0          60.0       23.0          846.0  30.1
# ..        ...      ...           ...        ...            ...   ...
# 753         0    181.0          88.0       44.0          510.0  43.3
# 755         1    128.0          88.0       39.0          110.0  36.5
# 760         2     88.0          58.0       26.0           16.0  28.4
# 763        10    101.0          76.0       48.0          180.0  32.9
# 765         5    121.0          72.0       23.0          112.0  26.2
#
#      Diabetes_Pedigree  Age  Class
# 3                0.167   21      0
# 4                2.288   33      1
# ...

# %%
print(csv_data.isnull().values.any())   # any NaN value is present or not ?
# Out:
# True

# %%
new_csv_data = csv_data.dropna()
print(new_csv_data.isnull().values.any())
# Out:
# False

# %%
csv_data.median()
# Out:
# Pregnant               3.0000
# Glucose              117.0000
# Diastolic_BP          72.0000
# Skin_Fold             29.0000
# Serum_Insulin        125.0000
# BMI                   32.3000
# Diabetes_Pedigree      0.3725
# Age                   29.0000
# Class                  0.0000
# dtype: float64

# %%
filling_missing_data = csv_data.fillna(csv_data.mean())   # filling the missing data with the mean of that column
print(filling_missing_data)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000     155.548223  33.6
# 1           1     85.0          66.0   29.00000     155.548223  26.6
# 2           8    183.0          64.0   29.15342     155.548223  23.3
# 3           1     89.0          66.0   23.00000      94.000000  28.1
# 4           0    137.0          40.0   35.00000     168.000000  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000     180.000000  32.9
# 764         2    122.0          70.0   27.00000     155.548223  36.8
# 765         5    121.0          72.0   23.00000     112.000000  26.2
# 766         1    126.0          60.0   29.15342     155.548223  30.1
# 767         1     93.0          70.0   31.00000     155.548223  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
print(filling_missing_data.head(3))
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0   35.00000     155.548223  33.6
# 1         1     85.0          66.0   29.00000     155.548223  26.6
# 2         8    183.0          64.0   29.15342     155.548223  23.3
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1

# %% [markdown]
# ## DATA TRANSFORMATION

# %%
csv_data.Class.value_counts()
# Out:
# Class
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
csv_data.replace([1,0],['M','F'])   # replace 1 with M and 0 with F in the Class column
# Out:
#     Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0          6    148.0          72.0       35.0            NaN  33.6
# 1          M     85.0          66.0       29.0            NaN  26.6
# 2          8    183.0          64.0        NaN            NaN  23.3
# 3          M     89.0          66.0       23.0           94.0  28.1
# 4          F    137.0          40.0       35.0          168.0  43.1
# ..       ...      ...           ...        ...            ...   ...
# 763       10    101.0          76.0       48.0          180.0  32.9
# 764        2    122.0          70.0       27.0            NaN  36.8
# 765        5    121.0          72.0       23.0          112.0  26.2
# 766        M    126.0          60.0        NaN            NaN  30.1
# 767        M     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age Class
# 0                0.627   50     M
# 1                0.351   31     F
# 2                0.672   32     M
# ...

# %%
# LABEL ENCODING

from sklearn.preprocessing import LabelEncoder   
label_encoder = LabelEncoder()
csv_data['encoded_BMI'] = label_encoder.fit_transform(csv_data['BMI'])
print(csv_data)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class  encoded_BMI
# 0                0.627   50      1          122
# ...

# %% [raw]
# DATA INTEGRATION

# %%
print(filling_missing_data)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000     155.548223  33.6
# 1           1     85.0          66.0   29.00000     155.548223  26.6
# 2           8    183.0          64.0   29.15342     155.548223  23.3
# 3           1     89.0          66.0   23.00000      94.000000  28.1
# 4           0    137.0          40.0   35.00000     168.000000  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000     180.000000  32.9
# 764         2    122.0          70.0   27.00000     155.548223  36.8
# 765         5    121.0          72.0   23.00000     112.000000  26.2
# 766         1    126.0          60.0   29.15342     155.548223  30.1
# 767         1     93.0          70.0   31.00000     155.548223  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
pd.merge(csv_data, filling_missing_data, on='BMI')
# Out:
#       Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0              6      148.0            72.0         35.0              NaN
# 1              6      148.0            72.0         35.0              NaN
# 2              6      148.0            72.0         35.0              NaN
# 3              6      148.0            72.0         35.0              NaN
# 4              6      148.0            72.0         35.0              NaN
# ...          ...        ...             ...          ...              ...
# 3628           1       93.0            70.0         31.0              NaN
# 3629           1       93.0            70.0         31.0              NaN
# 3630           1       93.0            70.0         31.0              NaN
# 3631           1       93.0            70.0         31.0              NaN
# 3632           1       93.0            70.0         31.0              NaN
#
#        BMI  Diabetes_Pedigree_x  Age_x  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.merge(csv_data,filling_missing_data,on=['BMI','Age']))
# Out:
#      Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0             6      148.0            72.0         35.0              NaN
# 1             1       85.0            66.0         29.0              NaN
# 2             8      183.0            64.0          NaN              NaN
# 3             1       89.0            66.0         23.0             94.0
# 4             0      137.0            40.0         35.0            168.0
# ..          ...        ...             ...          ...              ...
# 880          10      101.0            76.0         48.0            180.0
# 881           2      122.0            70.0         27.0              NaN
# 882           5      121.0            72.0         23.0            112.0
# 883           1      126.0            60.0          NaN              NaN
# 884           1       93.0            70.0         31.0              NaN
#
#       BMI  Diabetes_Pedigree_x  Age  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.merge(csv_data,filling_missing_data,on=['BMI'],how='right'))
# Out:
#       Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0            6.0      148.0            72.0         35.0              NaN
# 1            2.0      107.0            74.0         30.0            100.0
# 2            1.0      113.0            64.0         35.0              NaN
# 3            5.0       96.0            74.0         18.0             67.0
# 4            0.0      104.0            64.0         37.0             64.0
# ...          ...        ...             ...          ...              ...
# 3639         9.0      165.0            88.0          NaN              NaN
# 3640         3.0       89.0            74.0         16.0             85.0
# 3641         2.0       84.0            50.0         23.0             76.0
# 3642         7.0      142.0            90.0         24.0            480.0
# 3643         1.0       93.0            70.0         31.0              NaN
#
#        BMI  Diabetes_Pedigree_x  Age_x  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.merge(csv_data,filling_missing_data,on=['BMI'],how='left'))
# Out:
#       Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0              6      148.0            72.0         35.0              NaN
# 1              6      148.0            72.0         35.0              NaN
# 2              6      148.0            72.0         35.0              NaN
# 3              6      148.0            72.0         35.0              NaN
# 4              6      148.0            72.0         35.0              NaN
# ...          ...        ...             ...          ...              ...
# 3639           1       93.0            70.0         31.0              NaN
# 3640           1       93.0            70.0         31.0              NaN
# 3641           1       93.0            70.0         31.0              NaN
# 3642           1       93.0            70.0         31.0              NaN
# 3643           1       93.0            70.0         31.0              NaN
#
#        BMI  Diabetes_Pedigree_x  Age_x  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.merge(csv_data,filling_missing_data,on=['BMI'],how='inner'))
# Out:
#       Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0              6      148.0            72.0         35.0              NaN
# 1              6      148.0            72.0         35.0              NaN
# 2              6      148.0            72.0         35.0              NaN
# 3              6      148.0            72.0         35.0              NaN
# 4              6      148.0            72.0         35.0              NaN
# ...          ...        ...             ...          ...              ...
# 3628           1       93.0            70.0         31.0              NaN
# 3629           1       93.0            70.0         31.0              NaN
# 3630           1       93.0            70.0         31.0              NaN
# 3631           1       93.0            70.0         31.0              NaN
# 3632           1       93.0            70.0         31.0              NaN
#
#        BMI  Diabetes_Pedigree_x  Age_x  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.merge(csv_data,filling_missing_data,on=['BMI'],how='outer'))
# Out:
#       Pregnant_x  Glucose_x  Diastolic_BP_x  Skin_Fold_x  Serum_Insulin_x  \
# 0            1.0       83.0            68.0          NaN              NaN
# 1            1.0       83.0            68.0          NaN              NaN
# 2            1.0       83.0            68.0          NaN              NaN
# 3            1.0       97.0            70.0         15.0              NaN
# 4            1.0       97.0            70.0         15.0              NaN
# ...          ...        ...             ...          ...              ...
# 3650         0.0       94.0             NaN          NaN              NaN
# 3651         3.0       80.0             NaN          NaN              NaN
# 3652         6.0      114.0             NaN          NaN              NaN
# 3653         5.0      136.0            82.0          NaN              NaN
# 3654        10.0      115.0             NaN          NaN              NaN
#
#        BMI  Diabetes_Pedigree_x  Age_x  Class_x  encoded_BMI  Pregnant_y  \
# ...

# %%
print(pd.concat([csv_data,filling_missing_data]))
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0   35.00000            NaN  33.6
# 1           1     85.0          66.0   29.00000            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0   23.00000      94.000000  28.1
# 4           0    137.0          40.0   35.00000     168.000000  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0   48.00000     180.000000  32.9
# 764         2    122.0          70.0   27.00000     155.548223  36.8
# 765         5    121.0          72.0   23.00000     112.000000  26.2
# 766         1    126.0          60.0   29.15342     155.548223  30.1
# 767         1     93.0          70.0   31.00000     155.548223  30.4
#
#      Diabetes_Pedigree  Age  Class  encoded_BMI
# 0                0.627   50      1        122.0
# ...

# %%
print(pd.concat([csv_data,filling_missing_data],axis=1))
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class  encoded_BMI  Pregnant  Glucose  \
# 0                0.627   50      1          122         6    148.0
# ...

# %%
print(csv_data.mean())
# Out:
# Pregnant               3.845052
# Glucose              121.686763
# Diastolic_BP          72.405184
# Skin_Fold             29.153420
# Serum_Insulin        155.548223
# BMI                   32.457464
# Diabetes_Pedigree      0.471876
# Age                   33.240885
# Class                  0.348958
# encoded_BMI          114.656250
# dtype: float64

# %%
print(csv_data.mode())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0       1.0     99.0          70.0       32.0          105.0  32.0
# 1       NaN    100.0           NaN        NaN            NaN   NaN
#
#    Diabetes_Pedigree   Age  Class  encoded_BMI
# 0              0.254  22.0    0.0        108.0
# 1              0.258   NaN    NaN          NaN

# %%
print(csv_data.median())
# Out:
# Pregnant               3.0000
# Glucose              117.0000
# Diastolic_BP          72.0000
# Skin_Fold             29.0000
# Serum_Insulin        125.0000
# BMI                   32.3000
# Diabetes_Pedigree      0.3725
# Age                   29.0000
# Class                  0.0000
# encoded_BMI          112.0000
# dtype: float64

# %% [raw]
# DATA TRANSFORMATION

# %%
csv_data.Class.value_counts()
# Out:
# Class
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
csv_data['Class'].unique()
# Out:
# array([1, 0])

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(6,4))
plt.hist(csv_data['BMI'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(csv_data['Age'], bins=15, color='orange', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()
